# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Import the requests library.
import requests

import sys
sys.path.append('..')

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c1bde85b70694e931fc4b3224de00fc1

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:

        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Description": city_desc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | merauke
# Processing Record 2 of Set 1 | praia
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | puerto vallarta
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | vostok
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | thompson
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | zolotinka
# City not found. Skipping...
# Processing Record 13 of Set 1 | provideniya
# Processing Record 14 of Set 1 | salalah
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | hithadhoo
# Processing Record 19 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 1 | port elizabeth
# Processing Record 21 of Set 1 | tambura
# Processing Record 22 of Set 1 | zeya
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | kotelnich
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | beira
# Processing Record 32 of Set 1 | kruisfontein
# Processing Record 33 of Set 1 | nizhniy tsasuchey
# Processing Record 34 of Set 1 | luderitz
# Processing Record 35 of Set 1 | safwah
# City not found. Skipping...
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | pisco
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | ushuaia
# Processing Record 40 of Set 1 | mackay
# Processing Record 41 of Set 1 | cortland
# Processing Record 42 of Set 1 | buala
# Processing Record 43 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 1 | cockburn town
# Processing Record 45 of Set 1 | vila franca do campo
# Processing Record 46 of Set 1 | tiksi
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | kaeo
# Processing Record 1 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 2 | northam
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | mandalgovi
# Processing Record 5 of Set 2 | alvaraes
# Processing Record 6 of Set 2 | nago
# Processing Record 7 of Set 2 | dolgoderevenskoye
# Processing Record 8 of Set 2 | jiayuguan
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 2 | alofi
# Processing Record 14 of Set 2 | svetlaya
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | yerbogachen
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | iqaluit
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | flin flon
# Processing Record 21 of Set 2 | katsuura
# Processing Record 22 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | homer
# Processing Record 25 of Set 2 | balkanabat
# Processing Record 26 of Set 2 | segamat
# Processing Record 27 of Set 2 | presidencia roque saenz pena
# Processing Record 28 of Set 2 | icod de los vinos
# Processing Record 29 of Set 2 | saint-pierre
# Processing Record 30 of Set 2 | bathsheba
# Processing Record 31 of Set 2 | puerto escondido
# Processing Record 32 of Set 2 | santana do livramento
# Processing Record 33 of Set 2 | lira
# Processing Record 34 of Set 2 | winnemucca
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | conceicao do araguaia
# Processing Record 37 of Set 2 | nikki
# Processing Record 38 of Set 2 | santa fe
# Processing Record 39 of Set 2 | shingu
# Processing Record 40 of Set 2 | bethel
# Processing Record 41 of Set 2 | deputatskiy
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 2 | bhuj
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | comodoro rivadavia
# Processing Record 48 of Set 2 | marrakesh
# Processing Record 49 of Set 2 | saint george
# Processing Record 50 of Set 2 | padang
# Processing Record 1 of Set 3 | luganville
# Processing Record 2 of Set 3 | clayton
# Processing Record 3 of Set 3 | olafsvik
# Processing Record 4 of Set 3 | port alfred
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | pemba
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | ovre ardal
# Processing Record 11 of Set 3 | hualmay
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | beyneu
# Processing Record 14 of Set 3 | jijiga
# Processing Record 15 of Set 3 | sechura
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | qaanaaq
# Processing Record 18 of Set 3 | sawtell
# Processing Record 19 of Set 3 | lagoa
# Processing Record 20 of Set 3 | dodoma
# Processing Record 21 of Set 3 | navolato
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 3 | aswan
# Processing Record 26 of Set 3 | faanui
# Processing Record 27 of Set 3 | pavlovsk
# Processing Record 28 of Set 3 | los llanos de aridane
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | mikun
# Processing Record 31 of Set 3 | yongchang
# Processing Record 32 of Set 3 | upernavik
# Processing Record 33 of Set 3 | yunjinghong
# City not found. Skipping...
# Processing Record 34 of Set 3 | artyom
# Processing Record 35 of Set 3 | perth
# Processing Record 36 of Set 3 | victoria
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | hirara
# Processing Record 39 of Set 3 | leningradskiy
# Processing Record 40 of Set 3 | port-de-bouc
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | livingston
# Processing Record 43 of Set 3 | hojslev
# Processing Record 44 of Set 3 | pavilosta
# Processing Record 45 of Set 3 | belmonte
# Processing Record 46 of Set 3 | wawa
# Processing Record 47 of Set 3 | glendive
# Processing Record 48 of Set 3 | jardim
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | rundu
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | taoudenni
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | canto do buriti
# Processing Record 5 of Set 4 | ponta delgada
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | xining
# Processing Record 8 of Set 4 | beloha
# Processing Record 9 of Set 4 | yulara
# Processing Record 10 of Set 4 | dicabisagan
# Processing Record 11 of Set 4 | chokwe
# Processing Record 12 of Set 4 | luanda
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | alice springs
# Processing Record 15 of Set 4 | vardo
# Processing Record 16 of Set 4 | marawi
# Processing Record 17 of Set 4 | torbay
# Processing Record 18 of Set 4 | clyde river
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | carutapera
# Processing Record 21 of Set 4 | sao joao da barra
# Processing Record 22 of Set 4 | kumphawapi
# Processing Record 23 of Set 4 | gien
# Processing Record 24 of Set 4 | zabid
# Processing Record 25 of Set 4 | dunedin
# Processing Record 26 of Set 4 | havre-saint-pierre
# Processing Record 27 of Set 4 | severo-kurilsk
# Processing Record 28 of Set 4 | porto santo
# Processing Record 29 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 4 | kushiro
# Processing Record 31 of Set 4 | ouadda
# Processing Record 32 of Set 4 | tuktoyaktuk
# Processing Record 33 of Set 4 | kamaishi
# Processing Record 34 of Set 4 | mar del plata
# Processing Record 35 of Set 4 | natal
# Processing Record 36 of Set 4 | grindavik
# Processing Record 37 of Set 4 | vitim
# Processing Record 38 of Set 4 | san javier
# Processing Record 39 of Set 4 | kommunisticheskiy
# Processing Record 40 of Set 4 | brownsville
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | bubaque
# Processing Record 44 of Set 4 | timra
# Processing Record 45 of Set 4 | longyearbyen
# Processing Record 46 of Set 4 | mbanza-ngungu
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | tabuk
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | constitucion
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | veraval
# Processing Record 3 of Set 5 | morro bay
# Processing Record 4 of Set 5 | storebo
# Processing Record 5 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | barroualie
# City not found. Skipping...
# Processing Record 7 of Set 5 | nelspruit
# Processing Record 8 of Set 5 | chuy
# Processing Record 9 of Set 5 | biloela
# Processing Record 10 of Set 5 | fairbanks
# Processing Record 11 of Set 5 | arona
# Processing Record 12 of Set 5 | sakaiminato
# Processing Record 13 of Set 5 | dingle
# Processing Record 14 of Set 5 | codrington
# Processing Record 15 of Set 5 | goianesia
# Processing Record 16 of Set 5 | sao filipe
# Processing Record 17 of Set 5 | burnie
# Processing Record 18 of Set 5 | bokhan
# Processing Record 19 of Set 5 | ankang
# Processing Record 20 of Set 5 | hofn
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | ust-nera
# Processing Record 23 of Set 5 | rio gallegos
# Processing Record 24 of Set 5 | naze
# Processing Record 25 of Set 5 | yantal
# Processing Record 26 of Set 5 | mount gambier
# Processing Record 27 of Set 5 | westport
# Processing Record 28 of Set 5 | havoysund
# Processing Record 29 of Set 5 | nenjiang
# Processing Record 30 of Set 5 | bontang
# Processing Record 31 of Set 5 | phuket
# Processing Record 32 of Set 5 | la asuncion
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | shitanjing
# Processing Record 35 of Set 5 | havelock
# Processing Record 36 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | ketchikan
# Processing Record 40 of Set 5 | avera
# Processing Record 41 of Set 5 | patiya
# Processing Record 42 of Set 5 | auxerre
# Processing Record 43 of Set 5 | saskylakh
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | kieta
# Processing Record 46 of Set 5 | cidreira
# Processing Record 47 of Set 5 | lavrentiya
# Processing Record 48 of Set 5 | kailua
# Processing Record 49 of Set 5 | labuhan
# Processing Record 50 of Set 5 | calbuco
# Processing Record 1 of Set 6 | aklavik
# Processing Record 2 of Set 6 | lac du bonnet
# Processing Record 3 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 4 of Set 6 | haines junction
# Processing Record 5 of Set 6 | christchurch
# Processing Record 6 of Set 6 | russell
# Processing Record 7 of Set 6 | peniche
# Processing Record 8 of Set 6 | bilibino
# Processing Record 9 of Set 6 | tchamba
# Processing Record 10 of Set 6 | chara
# Processing Record 11 of Set 6 | husavik
# Processing Record 12 of Set 6 | srandakan
# Processing Record 13 of Set 6 | tuatapere
# Processing Record 14 of Set 6 | riohacha
# Processing Record 15 of Set 6 | porbandar
# Processing Record 16 of Set 6 | te anau
# Processing Record 17 of Set 6 | kula
# Processing Record 18 of Set 6 | richards bay
# Processing Record 19 of Set 6 | bella union
# Processing Record 20 of Set 6 | kaitangata
# Processing Record 21 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 6 | opuwo
# Processing Record 23 of Set 6 | bonavista
# Processing Record 24 of Set 6 | geraldton
# Processing Record 25 of Set 6 | lar
# Processing Record 26 of Set 6 | danielskuil
# Processing Record 27 of Set 6 | myitkyina
# Processing Record 28 of Set 6 | la ronge
# Processing Record 29 of Set 6 | boguchany
# Processing Record 30 of Set 6 | dakar
# Processing Record 31 of Set 6 | port lincoln
# Processing Record 32 of Set 6 | tokur
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | oro valley
# Processing Record 35 of Set 6 | yumen
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | san julian
# Processing Record 38 of Set 6 | caibarien
# Processing Record 39 of Set 6 | quesnel
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | velikiy ustyug
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | bivolari
# Processing Record 44 of Set 6 | pandan
# Processing Record 45 of Set 6 | shimoda
# Processing Record 46 of Set 6 | prince rupert
# Processing Record 47 of Set 6 | taganak
# Processing Record 48 of Set 6 | mahon
# Processing Record 49 of Set 6 | khorixas
# Processing Record 50 of Set 6 | new iberia
# Processing Record 1 of Set 7 | kentau
# Processing Record 2 of Set 7 | takoradi
# Processing Record 3 of Set 7 | mangai
# Processing Record 4 of Set 7 | visnes
# Processing Record 5 of Set 7 | galle
# Processing Record 6 of Set 7 | san matias
# Processing Record 7 of Set 7 | zaltan
# Processing Record 8 of Set 7 | moses lake
# Processing Record 9 of Set 7 | charlestown
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | garissa
# Processing Record 12 of Set 7 | illapel
# Processing Record 13 of Set 7 | elbistan
# Processing Record 14 of Set 7 | kalmunai
# Processing Record 15 of Set 7 | paragominas
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | sorong
# Processing Record 18 of Set 7 | yaan
# Processing Record 19 of Set 7 | lokosovo
# Processing Record 20 of Set 7 | hay river
# Processing Record 21 of Set 7 | hargeysa
# Processing Record 22 of Set 7 | chihuahua
# Processing Record 23 of Set 7 | matara
# Processing Record 24 of Set 7 | alamosa
# Processing Record 25 of Set 7 | nakamura
# Processing Record 26 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | midland
# Processing Record 28 of Set 7 | xingyi
# Processing Record 29 of Set 7 | lensk
# Processing Record 30 of Set 7 | umm lajj
# Processing Record 31 of Set 7 | odweyne
# Processing Record 32 of Set 7 | krasnoselkup
# Processing Record 33 of Set 7 | launceston
# Processing Record 34 of Set 7 | ahipara
# Processing Record 35 of Set 7 | pindiga
# Processing Record 36 of Set 7 | talas
# Processing Record 37 of Set 7 | cabo san lucas
# Processing Record 38 of Set 7 | goba
# Processing Record 39 of Set 7 | macklin
# Processing Record 40 of Set 7 | guajara
# Processing Record 41 of Set 7 | lixourion
# Processing Record 42 of Set 7 | jizan
# Processing Record 43 of Set 7 | linxia
# Processing Record 44 of Set 7 | akcaabat
# Processing Record 45 of Set 7 | pokhara
# Processing Record 46 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 7 | sigli
# Processing Record 48 of Set 7 | minab
# Processing Record 49 of Set 7 | tias
# Processing Record 50 of Set 7 | namuac
# Processing Record 1 of Set 8 | shankargarh
# Processing Record 2 of Set 8 | liverpool
# Processing Record 3 of Set 8 | khani
# Processing Record 4 of Set 8 | meulaboh
# Processing Record 5 of Set 8 | nemuro
# Processing Record 6 of Set 8 | san miguel de cauri
# Processing Record 7 of Set 8 | pacific grove
# Processing Record 8 of Set 8 | berlevag
# Processing Record 9 of Set 8 | jacqueville
# Processing Record 10 of Set 8 | juye
# Processing Record 11 of Set 8 | micheweni
# Processing Record 12 of Set 8 | talagang
# Processing Record 13 of Set 8 | ayagoz
# Processing Record 14 of Set 8 | sept-iles
# Processing Record 15 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 8 | bani walid
# Processing Record 17 of Set 8 | mehamn
# Processing Record 18 of Set 8 | duku
# Processing Record 19 of Set 8 | roald
# Processing Record 20 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 8 | broken hill
# Processing Record 22 of Set 8 | nouakchott
# Processing Record 23 of Set 8 | mahebourg
# Processing Record 24 of Set 8 | buchanan
# Processing Record 25 of Set 8 | udachnyy
# Processing Record 26 of Set 8 | meadow lake
# Processing Record 27 of Set 8 | goderich
# Processing Record 28 of Set 8 | klaksvik
# Processing Record 29 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 8 | bambous virieux
# Processing Record 31 of Set 8 | sangod
# Processing Record 32 of Set 8 | pavlohrad
# Processing Record 33 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 8 | chor
# Processing Record 35 of Set 8 | waseca
# Processing Record 36 of Set 8 | sur
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | kranjska gora
# Processing Record 39 of Set 8 | puerto carreno
# Processing Record 40 of Set 8 | knysna
# Processing Record 41 of Set 8 | gari
# Processing Record 42 of Set 8 | hasaki
# Processing Record 43 of Set 8 | miandrivazo
# Processing Record 44 of Set 8 | lima
# Processing Record 45 of Set 8 | hambantota
# Processing Record 46 of Set 8 | bucak
# Processing Record 47 of Set 8 | puerto princesa
# Processing Record 48 of Set 8 | ulaanbaatar
# Processing Record 49 of Set 8 | diego de almagro
# Processing Record 50 of Set 8 | agirish
# Processing Record 1 of Set 9 | leh
# Processing Record 2 of Set 9 | oudtshoorn
# Processing Record 3 of Set 9 | san carlos de bariloche
# Processing Record 4 of Set 9 | new norfolk
# Processing Record 5 of Set 9 | itoman
# Processing Record 6 of Set 9 | nyurba
# Processing Record 7 of Set 9 | cuamba
# Processing Record 8 of Set 9 | mercedes
# Processing Record 9 of Set 9 | edd
# Processing Record 10 of Set 9 | portland
# Processing Record 11 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 9 | la tuque
# Processing Record 13 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 9 | kavaratti
# Processing Record 16 of Set 9 | dhidhdhoo
# Processing Record 17 of Set 9 | luang prabang
# Processing Record 18 of Set 9 | kahului
# Processing Record 19 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 20 of Set 9 | cap malheureux
# Processing Record 21 of Set 9 | tunghsiao
# City not found. Skipping...
# Processing Record 22 of Set 9 | marsh harbour
# Processing Record 23 of Set 9 | sampit
# Processing Record 24 of Set 9 | jalu
# Processing Record 25 of Set 9 | port blair
# Processing Record 26 of Set 9 | college
# Processing Record 27 of Set 9 | sharan
# Processing Record 28 of Set 9 | victor harbor
# Processing Record 29 of Set 9 | san cristobal
# Processing Record 30 of Set 9 | necochea
# Processing Record 31 of Set 9 | diamantino
# Processing Record 32 of Set 9 | roma
# Processing Record 33 of Set 9 | kirkland lake
# Processing Record 34 of Set 9 | holsted
# Processing Record 35 of Set 9 | aloleng
# Processing Record 36 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 9 | bokoro
# Processing Record 38 of Set 9 | hokitika
# Processing Record 39 of Set 9 | pinotepa nacional
# Processing Record 40 of Set 9 | pasaje
# Processing Record 41 of Set 9 | gull lake
# Processing Record 42 of Set 9 | conguaco
# Processing Record 43 of Set 9 | nichinan
# Processing Record 44 of Set 9 | shakawe
# Processing Record 45 of Set 9 | usinsk
# Processing Record 46 of Set 9 | chiredzi
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | kholtoson
# Processing Record 49 of Set 9 | adrar
# Processing Record 50 of Set 9 | yukhnov
# Processing Record 1 of Set 10 | yabrud
# Processing Record 2 of Set 10 | itanhaem
# Processing Record 3 of Set 10 | guerrero negro
# Processing Record 4 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | vagur
# Processing Record 7 of Set 10 | gaoua
# Processing Record 8 of Set 10 | creston
# Processing Record 9 of Set 10 | yar-sale
# Processing Record 10 of Set 10 | ye
# City not found. Skipping...
# Processing Record 11 of Set 10 | doha
# Processing Record 12 of Set 10 | mulege
# Processing Record 13 of Set 10 | byron bay
# Processing Record 14 of Set 10 | caraz
# Processing Record 15 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 10 | kununurra
# Processing Record 17 of Set 10 | bagan
# Processing Record 18 of Set 10 | tublay
# Processing Record 19 of Set 10 | mount isa
# Processing Record 20 of Set 10 | preobrazheniye
# Processing Record 21 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 10 | muros
# Processing Record 23 of Set 10 | araouane
# Processing Record 24 of Set 10 | rostovka
# Processing Record 25 of Set 10 | tual
# Processing Record 26 of Set 10 | abonnema
# Processing Record 27 of Set 10 | chingirlau
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | nanortalik
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | lakes entrance
# Processing Record 32 of Set 10 | panaba
# Processing Record 33 of Set 10 | sungaipenuh
# Processing Record 34 of Set 10 | leiyang
# Processing Record 35 of Set 10 | gandorhun
# Processing Record 36 of Set 10 | tocopilla
# Processing Record 37 of Set 10 | foam lake
# Processing Record 38 of Set 10 | shenjiamen
# Processing Record 39 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 40 of Set 10 | bunia
# Processing Record 41 of Set 10 | luoyang
# Processing Record 42 of Set 10 | kijang
# Processing Record 43 of Set 10 | katherine
# Processing Record 44 of Set 10 | ancud
# Processing Record 45 of Set 10 | paamiut
# Processing Record 46 of Set 10 | nesbyen
# Processing Record 47 of Set 10 | gordeyevka
# Processing Record 48 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 10 | beringovskiy
# Processing Record 50 of Set 10 | henties bay
# Processing Record 1 of Set 11 | tshane
# Processing Record 2 of Set 11 | xian
# Processing Record 3 of Set 11 | ebano
# City not found. Skipping...
# Processing Record 4 of Set 11 | elat
# Processing Record 5 of Set 11 | nizhnedevitsk
# Processing Record 6 of Set 11 | verkhnyaya salda
# Processing Record 7 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 11 | lai
# Processing Record 10 of Set 11 | gualeguaychu
# Processing Record 11 of Set 11 | awbari
# Processing Record 12 of Set 11 | ovruch
# Processing Record 13 of Set 11 | marzuq
# Processing Record 14 of Set 11 | omsukchan
# Processing Record 15 of Set 11 | manggar
# Processing Record 16 of Set 11 | boden
# Processing Record 17 of Set 11 | komsomolskiy
# Processing Record 18 of Set 11 | mahanoro
# Processing Record 19 of Set 11 | mogadishu
# Processing Record 20 of Set 11 | jimo
# Processing Record 21 of Set 11 | denpasar
# Processing Record 22 of Set 11 | okhotsk
# Processing Record 23 of Set 11 | lively
# Processing Record 24 of Set 11 | romny
# Processing Record 25 of Set 11 | vvedenskoye
# Processing Record 26 of Set 11 | shihezi
# Processing Record 27 of Set 11 | bay roberts
# Processing Record 28 of Set 11 | korla
# Processing Record 29 of Set 11 | rocha
# Processing Record 30 of Set 11 | mayumba
# Processing Record 31 of Set 11 | nazca
# Processing Record 32 of Set 11 | sol-iletsk
# Processing Record 33 of Set 11 | camana
# Processing Record 34 of Set 11 | camargo
# Processing Record 35 of Set 11 | timizart
# Processing Record 36 of Set 11 | coahuayana
# Processing Record 37 of Set 11 | linden
# Processing Record 38 of Set 11 | plouzane
# Processing Record 39 of Set 11 | chandia
# Processing Record 40 of Set 11 | ribas do rio pardo
# Processing Record 41 of Set 11 | kloulklubed
# Processing Record 42 of Set 11 | bianzhuang
# Processing Record 43 of Set 11 | george town
# Processing Record 44 of Set 11 | half moon bay
# Processing Record 45 of Set 11 | bayan
# Processing Record 46 of Set 11 | san quintin
# Processing Record 47 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 48 of Set 11 | prieska
# Processing Record 49 of Set 11 | genhe
# Processing Record 50 of Set 11 | leesburg
# Processing Record 1 of Set 12 | kitui
# Processing Record 2 of Set 12 | srednekolymsk
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | airai
# Processing Record 5 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 12 | ilinskoye-khovanskoye
# Processing Record 7 of Set 12 | gouyave
# Processing Record 8 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 12 | badou
# Processing Record 10 of Set 12 | baiyin
# Processing Record 11 of Set 12 | angoche
# Processing Record 12 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 12 | cobourg
# Processing Record 14 of Set 12 | nuuk
# Processing Record 15 of Set 12 | haimen
# Processing Record 16 of Set 12 | pombia
# Processing Record 17 of Set 12 | mareeba
# Processing Record 18 of Set 12 | mayo
# Processing Record 19 of Set 12 | waspan
# Processing Record 20 of Set 12 | aksu
# Processing Record 21 of Set 12 | mahibadhoo
# Processing Record 22 of Set 12 | ambilobe
# Processing Record 23 of Set 12 | tazovskiy
# Processing Record 24 of Set 12 | barra dos coqueiros
# Processing Record 25 of Set 12 | raton
# Processing Record 26 of Set 12 | nizhniy kuranakh
# Processing Record 27 of Set 12 | port-cartier
# Processing Record 28 of Set 12 | meybod
# Processing Record 29 of Set 12 | port hardy
# Processing Record 30 of Set 12 | katerero
# Processing Record 31 of Set 12 | commerce
# Processing Record 32 of Set 12 | kaabong
# Processing Record 33 of Set 12 | carlsbad
# Processing Record 34 of Set 12 | sarankhola
# Processing Record 35 of Set 12 | biak
# Processing Record 36 of Set 12 | menomonie
# Processing Record 37 of Set 12 | el colomo
# Processing Record 38 of Set 12 | evensk
# Processing Record 39 of Set 12 | raudeberg
# Processing Record 40 of Set 12 | guru har sahai
# Processing Record 41 of Set 12 | san carlos
# Processing Record 42 of Set 12 | ambulu
# Processing Record 43 of Set 12 | sabang
# Processing Record 44 of Set 12 | kpandae
# Processing Record 45 of Set 12 | rubio
# Processing Record 46 of Set 12 | bergerac
# Processing Record 47 of Set 12 | buta
# Processing Record 48 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 12 | mao
# Processing Record 50 of Set 12 | pangnirtung
# Processing Record 1 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 13 | diffa
# Processing Record 3 of Set 13 | kisanga
# Processing Record 4 of Set 13 | namibe
# Processing Record 5 of Set 13 | sisimiut
# Processing Record 6 of Set 13 | cap-aux-meules
# Processing Record 7 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 13 | gamba
# Processing Record 9 of Set 13 | horta
# Processing Record 10 of Set 13 | batemans bay
# Processing Record 11 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 13 | nyrob
# Processing Record 13 of Set 13 | atar
# Processing Record 14 of Set 13 | zelenoborsk
# Processing Record 15 of Set 13 | date
# Processing Record 16 of Set 13 | fort nelson
# Processing Record 17 of Set 13 | bukan
# Processing Record 18 of Set 13 | yusva
# City not found. Skipping...
# Processing Record 19 of Set 13 | bajil
# Processing Record 20 of Set 13 | bara
# Processing Record 21 of Set 13 | inirida
# Processing Record 22 of Set 13 | deogarh
# Processing Record 23 of Set 13 | poum
# Processing Record 24 of Set 13 | barreirinha
# Processing Record 25 of Set 13 | salvador
# Processing Record 26 of Set 13 | sulurpeta
# City not found. Skipping...
# Processing Record 27 of Set 13 | sri aman
# Processing Record 28 of Set 13 | hervey bay
# Processing Record 29 of Set 13 | houma
# Processing Record 30 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 31 of Set 13 | ambanja
# Processing Record 32 of Set 13 | palmer
# Processing Record 33 of Set 13 | zemio
# Processing Record 34 of Set 13 | eugene
# Processing Record 35 of Set 13 | tyristrand
# Processing Record 36 of Set 13 | garoua
# Processing Record 37 of Set 13 | dong hoi
# Processing Record 38 of Set 13 | nakusp
# Processing Record 39 of Set 13 | carbonia
# Processing Record 40 of Set 13 | lithakia
# Processing Record 41 of Set 13 | bud
# Processing Record 42 of Set 13 | krasnoborsk
# Processing Record 43 of Set 13 | bakreswar
# Processing Record 44 of Set 13 | novaya malykla
# Processing Record 45 of Set 13 | rockhampton
# Processing Record 46 of Set 13 | williams lake
# Processing Record 47 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 13 | oistins
# Processing Record 49 of Set 13 | looc
# Processing Record 50 of Set 13 | tessalit
# Processing Record 1 of Set 14 | corinto
# Processing Record 2 of Set 14 | thiruvananthapuram
# Processing Record 3 of Set 14 | pedernales
# Processing Record 4 of Set 14 | nata
# Processing Record 5 of Set 14 | gogrial
# Processing Record 6 of Set 14 | policoro
# Processing Record 7 of Set 14 | ranau
# Processing Record 8 of Set 14 | irbit
# Processing Record 9 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 14 | we
# City not found. Skipping...
# Processing Record 11 of Set 14 | yankton
# Processing Record 12 of Set 14 | rizhao
# Processing Record 13 of Set 14 | mezhdurechensk
# Processing Record 14 of Set 14 | kharan
# Processing Record 15 of Set 14 | maniitsoq
# Processing Record 16 of Set 14 | obo
# Processing Record 17 of Set 14 | nioki
# Processing Record 18 of Set 14 | mardin
# Processing Record 19 of Set 14 | praya
# Processing Record 20 of Set 14 | sacile
# Processing Record 21 of Set 14 | altamont
# Processing Record 22 of Set 14 | nakskov
# Processing Record 23 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 14 | moindou
# Processing Record 25 of Set 14 | dongsheng
# Processing Record 26 of Set 14 | fare
# Processing Record 27 of Set 14 | nome
# Processing Record 28 of Set 14 | kabale
# Processing Record 29 of Set 14 | zhigansk
# Processing Record 30 of Set 14 | general roca
# Processing Record 31 of Set 14 | muzhi
# Processing Record 32 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 14 | mananjary
# Processing Record 34 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 14 | gatesville
# Processing Record 36 of Set 14 | roros
# Processing Record 37 of Set 14 | sedalia
# Processing Record 38 of Set 14 | kutum
# Processing Record 39 of Set 14 | puerto leguizamo
# Processing Record 40 of Set 14 | sierpc
# Processing Record 41 of Set 14 | kindersley
# Processing Record 42 of Set 14 | forest grove
# Processing Record 43 of Set 14 | chemal
# Processing Record 44 of Set 14 | dzhebariki-khaya
# Processing Record 45 of Set 14 | oban
# Processing Record 46 of Set 14 | oranjemund
# Processing Record 47 of Set 14 | boma
# Processing Record 48 of Set 14 | port hedland
# Processing Record 49 of Set 14 | zharkent
# Processing Record 50 of Set 14 | balabac
# Processing Record 1 of Set 15 | solnechnyy
# Processing Record 2 of Set 15 | grootfontein
# Processing Record 3 of Set 15 | boa vista
# Processing Record 4 of Set 15 | port augusta
# Processing Record 5 of Set 15 | matamoros
# Processing Record 6 of Set 15 | nelson
# Processing Record 7 of Set 15 | batagay-alyta
# Processing Record 8 of Set 15 | dolinsk
# Processing Record 9 of Set 15 | san isidro
# Processing Record 10 of Set 15 | lalmanir hat
# City not found. Skipping...
# Processing Record 11 of Set 15 | daye
# Processing Record 12 of Set 15 | tanout
# Processing Record 13 of Set 15 | cayenne
# Processing Record 14 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 15 of Set 15 | entre rios
# Processing Record 16 of Set 15 | kabo
# Processing Record 17 of Set 15 | babu
# Processing Record 18 of Set 15 | rawson
# Processing Record 19 of Set 15 | atambua
# Processing Record 20 of Set 15 | saiha
# Processing Record 21 of Set 15 | berlin
# Processing Record 22 of Set 15 | orebro
# Processing Record 23 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 24 of Set 15 | galesong
# Processing Record 25 of Set 15 | magadan
# Processing Record 26 of Set 15 | saint anthony
# Processing Record 27 of Set 15 | alghero
# Processing Record 28 of Set 15 | duartina
# Processing Record 29 of Set 15 | sandakan
# Processing Record 30 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 31 of Set 15 | danjiangkou
# Processing Record 32 of Set 15 | portel
# Processing Record 33 of Set 15 | erzin
# Processing Record 34 of Set 15 | ballina
# Processing Record 35 of Set 15 | luwuk
# Processing Record 36 of Set 15 | juazeiro
# Processing Record 37 of Set 15 | nanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Merauke  -8.47  140.33     72.91        76          31        9.57
# 1            Praia  14.92  -23.51     82.40        58          20       12.75
# 2         Khatanga  71.97  102.50     43.97        67           2       12.19
# 3           Atuona  -9.80 -139.03     78.60        77          36       15.43
# 4  Puerto Vallarta  20.62 -105.23     90.00        62          75        9.17
# 5            Kapaa  22.08 -159.32     82.40        69          20       12.75
# 6           Vostok  46.49  135.88     46.62        91         100        4.03
# 7        Carnarvon -24.87  113.63     64.40        72          40        9.17
# 8         Thompson  55.74  -97.86     78.80        41          40       10.29
# 9            Vaini -21.20 -175.20     71.60       100          90        3.36
#
#                    Description
# 0             scattered clouds
# 1                   few clouds
# 2                    clear sky
# 3                   light rain
# 4                broken clouds
# 5                   few clouds
# 6              overcast clouds
# 7             scattered clouds
# 8             scattered clouds
# 9  light intensity shower rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
