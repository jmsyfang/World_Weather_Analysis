# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Import the requests library.
import requests

import sys
sys.path.append('..')

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c1bde85b70694e931fc4b3224de00fc1

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
        
# Run an API request for each of the cities.
    try:

        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Description": city_desc,
                            "Country": city_country})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | salinopolis
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | luanda
# Processing Record 6 of Set 1 | ancud
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | east london
# Processing Record 10 of Set 1 | codrington
# Processing Record 11 of Set 1 | vestmannaeyjar
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | fortuna
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | gat
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | asau
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | celina
# Processing Record 22 of Set 1 | itamaraca
# Processing Record 23 of Set 1 | mahina
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | malegaon
# Processing Record 26 of Set 1 | hilo
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | chokurdakh
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | lompoc
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | faya
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | vagur
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | lufkin
# Processing Record 37 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 1 | beloostrov
# Processing Record 39 of Set 1 | taoudenni
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | nanortalik
# Processing Record 42 of Set 1 | bridlington
# Processing Record 43 of Set 1 | san andres
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | zhigansk
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | lamesa
# Processing Record 1 of Set 2 | maneromango
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | betanzos
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | henties bay
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | caravelas
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | beloha
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | belmonte
# Processing Record 12 of Set 2 | necochea
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | flinders
# Processing Record 17 of Set 2 | bellefontaine
# Processing Record 18 of Set 2 | channel-port aux basques
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | fairbanks
# Processing Record 21 of Set 2 | cancun
# Processing Record 22 of Set 2 | pacific grove
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | tevriz
# Processing Record 26 of Set 2 | macklin
# Processing Record 27 of Set 2 | san juan bautista
# Processing Record 28 of Set 2 | santo augusto
# Processing Record 29 of Set 2 | kondopoga
# Processing Record 30 of Set 2 | kapaa
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | murmashi
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | roma
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 2 | menongue
# Processing Record 40 of Set 2 | dubreka
# Processing Record 41 of Set 2 | birao
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | saint-denis
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | gladstone
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | valparaiso
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | thompson
# Processing Record 50 of Set 2 | canutama
# Processing Record 1 of Set 3 | adeje
# Processing Record 2 of Set 3 | adrar
# Processing Record 3 of Set 3 | den helder
# Processing Record 4 of Set 3 | vaini
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | shakiso
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | akyab
# Processing Record 10 of Set 3 | provideniya
# Processing Record 11 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 3 | severodvinsk
# Processing Record 13 of Set 3 | galle
# Processing Record 14 of Set 3 | weihe
# Processing Record 15 of Set 3 | rumonge
# Processing Record 16 of Set 3 | upernavik
# Processing Record 17 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 3 | mae tha
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | alyangula
# Processing Record 21 of Set 3 | vrises
# Processing Record 22 of Set 3 | shirokiy
# Processing Record 23 of Set 3 | pitimbu
# Processing Record 24 of Set 3 | baykit
# Processing Record 25 of Set 3 | umtata
# Processing Record 26 of Set 3 | guerrero negro
# Processing Record 27 of Set 3 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 3 | port hardy
# Processing Record 29 of Set 3 | porto murtinho
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | magadan
# Processing Record 32 of Set 3 | comodoro rivadavia
# Processing Record 33 of Set 3 | krasnooktyabrskiy
# Processing Record 34 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 3 | melo
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | immokalee
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | byron bay
# Processing Record 41 of Set 3 | mumford
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | saint-francois
# Processing Record 45 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | tabas
# Processing Record 49 of Set 3 | shahpura
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | tenextatiloyan
# City not found. Skipping...
# Processing Record 2 of Set 4 | xining
# Processing Record 3 of Set 4 | kimbe
# Processing Record 4 of Set 4 | constitucion
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | fare
# Processing Record 8 of Set 4 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 4 | batemans bay
# Processing Record 10 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 4 | englewood
# Processing Record 12 of Set 4 | zhengjiatun
# Processing Record 13 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 4 | amposta
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | port hedland
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | northam
# Processing Record 20 of Set 4 | clyde river
# Processing Record 21 of Set 4 | vao
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | port alfred
# Processing Record 24 of Set 4 | barra patuca
# Processing Record 25 of Set 4 | elbistan
# Processing Record 26 of Set 4 | broken hill
# Processing Record 27 of Set 4 | saint-augustin
# Processing Record 28 of Set 4 | eydhafushi
# Processing Record 29 of Set 4 | poum
# Processing Record 30 of Set 4 | anadyr
# Processing Record 31 of Set 4 | kamskiye polyany
# Processing Record 32 of Set 4 | sao felix do xingu
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | dutse
# Processing Record 36 of Set 4 | cabedelo
# Processing Record 37 of Set 4 | lata
# Processing Record 38 of Set 4 | paita
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | newport
# Processing Record 41 of Set 4 | zhoucheng
# Processing Record 42 of Set 4 | saint-georges
# Processing Record 43 of Set 4 | tura
# Processing Record 44 of Set 4 | kaka
# Processing Record 45 of Set 4 | palmer
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | bongandanga
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | cheremushskiy
# Processing Record 1 of Set 5 | paamiut
# Processing Record 2 of Set 5 | mao
# Processing Record 3 of Set 5 | rehoboth
# Processing Record 4 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 5 of Set 5 | yibin
# Processing Record 6 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 5 | tiarei
# Processing Record 8 of Set 5 | san pedro
# Processing Record 9 of Set 5 | nisporeni
# Processing Record 10 of Set 5 | ahipara
# Processing Record 11 of Set 5 | fort frances
# Processing Record 12 of Set 5 | yerbogachen
# Processing Record 13 of Set 5 | havoysund
# Processing Record 14 of Set 5 | gualaquiza
# Processing Record 15 of Set 5 | champerico
# Processing Record 16 of Set 5 | pisco
# Processing Record 17 of Set 5 | enshi
# Processing Record 18 of Set 5 | tanout
# Processing Record 19 of Set 5 | acarau
# Processing Record 20 of Set 5 | tailai
# Processing Record 21 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 5 | santa rosa
# Processing Record 23 of Set 5 | saskylakh
# Processing Record 24 of Set 5 | plavsk
# Processing Record 25 of Set 5 | narsaq
# Processing Record 26 of Set 5 | la foa
# Processing Record 27 of Set 5 | soyo
# Processing Record 28 of Set 5 | waipawa
# Processing Record 29 of Set 5 | gasa
# Processing Record 30 of Set 5 | the valley
# Processing Record 31 of Set 5 | olinda
# Processing Record 32 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 5 | kushiro
# Processing Record 35 of Set 5 | sabang
# Processing Record 36 of Set 5 | aksu
# Processing Record 37 of Set 5 | strai
# Processing Record 38 of Set 5 | labuhan
# Processing Record 39 of Set 5 | vreed en hoop
# City not found. Skipping...
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | cherskiy
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | geraldton
# Processing Record 44 of Set 5 | namatanai
# Processing Record 45 of Set 5 | shenjiamen
# Processing Record 46 of Set 5 | bethlehem
# Processing Record 47 of Set 5 | shimoda
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | pangai
# Processing Record 50 of Set 5 | santa fe
# Processing Record 1 of Set 6 | palana
# Processing Record 2 of Set 6 | dwarka
# Processing Record 3 of Set 6 | ormara
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | vilhena
# Processing Record 6 of Set 6 | abomsa
# Processing Record 7 of Set 6 | tres palos
# Processing Record 8 of Set 6 | belozerskoye
# Processing Record 9 of Set 6 | riohacha
# Processing Record 10 of Set 6 | haines junction
# Processing Record 11 of Set 6 | vagay
# Processing Record 12 of Set 6 | roros
# Processing Record 13 of Set 6 | kungurtug
# Processing Record 14 of Set 6 | smithers
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 6 | agadez
# Processing Record 17 of Set 6 | saint-jacques
# Processing Record 18 of Set 6 | santiago del estero
# Processing Record 19 of Set 6 | bull savanna
# Processing Record 20 of Set 6 | qaanaaq
# Processing Record 21 of Set 6 | manzil salim
# Processing Record 22 of Set 6 | muli
# Processing Record 23 of Set 6 | altay
# Processing Record 24 of Set 6 | riyadh
# Processing Record 25 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 6 | berea
# Processing Record 28 of Set 6 | skibbereen
# Processing Record 29 of Set 6 | catio
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | port blair
# Processing Record 32 of Set 6 | ostrovnoy
# Processing Record 33 of Set 6 | marondera
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | tingi
# Processing Record 36 of Set 6 | dikson
# Processing Record 37 of Set 6 | prenzlau
# Processing Record 38 of Set 6 | puro
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | ouegoa
# Processing Record 41 of Set 6 | angoche
# Processing Record 42 of Set 6 | ossora
# Processing Record 43 of Set 6 | san quintin
# Processing Record 44 of Set 6 | sitka
# Processing Record 45 of Set 6 | greeley
# Processing Record 46 of Set 6 | numbrecht
# Processing Record 47 of Set 6 | leningradskiy
# Processing Record 48 of Set 6 | maceio
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | romitan
# Processing Record 1 of Set 7 | na klang
# Processing Record 2 of Set 7 | tilichiki
# Processing Record 3 of Set 7 | hami
# Processing Record 4 of Set 7 | hanzhong
# Processing Record 5 of Set 7 | anda
# Processing Record 6 of Set 7 | rio grande
# Processing Record 7 of Set 7 | pareora
# Processing Record 8 of Set 7 | talnakh
# Processing Record 9 of Set 7 | saint anthony
# Processing Record 10 of Set 7 | pudozh
# Processing Record 11 of Set 7 | cabras
# Processing Record 12 of Set 7 | bengkulu
# Processing Record 13 of Set 7 | hasaki
# Processing Record 14 of Set 7 | karwar
# Processing Record 15 of Set 7 | belyy yar
# Processing Record 16 of Set 7 | dharchula
# Processing Record 17 of Set 7 | ribeira brava
# Processing Record 18 of Set 7 | corinth
# Processing Record 19 of Set 7 | tambo
# Processing Record 20 of Set 7 | sibu
# Processing Record 21 of Set 7 | hualmay
# Processing Record 22 of Set 7 | ballina
# Processing Record 23 of Set 7 | morwa
# Processing Record 24 of Set 7 | kidal
# Processing Record 25 of Set 7 | kavieng
# Processing Record 26 of Set 7 | georgetown
# Processing Record 27 of Set 7 | tutoia
# Processing Record 28 of Set 7 | vila franca do campo
# Processing Record 29 of Set 7 | campoverde
# Processing Record 30 of Set 7 | ribeira grande
# Processing Record 31 of Set 7 | pingliang
# Processing Record 32 of Set 7 | kribi
# Processing Record 33 of Set 7 | tongsa
# City not found. Skipping...
# Processing Record 34 of Set 7 | garmsar
# Processing Record 35 of Set 7 | hambantota
# Processing Record 36 of Set 7 | samarai
# Processing Record 37 of Set 7 | kaeo
# Processing Record 38 of Set 7 | severo-kurilsk
# Processing Record 39 of Set 7 | sao gabriel da cachoeira
# Processing Record 40 of Set 7 | paralimni
# Processing Record 41 of Set 7 | buala
# Processing Record 42 of Set 7 | weligama
# Processing Record 43 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 7 | khuzhir
# Processing Record 46 of Set 7 | nhulunbuy
# Processing Record 47 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 48 of Set 7 | general pico
# Processing Record 49 of Set 7 | killarney
# Processing Record 50 of Set 7 | mangan
# Processing Record 1 of Set 8 | carora
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | mandalgovi
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | mporokoso
# Processing Record 6 of Set 8 | amahai
# Processing Record 7 of Set 8 | schuttorf
# Processing Record 8 of Set 8 | linxia
# Processing Record 9 of Set 8 | pochutla
# Processing Record 10 of Set 8 | verkhoturye
# Processing Record 11 of Set 8 | kruisfontein
# Processing Record 12 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 13 of Set 8 | clarence town
# Processing Record 14 of Set 8 | comana
# Processing Record 15 of Set 8 | kirando
# Processing Record 16 of Set 8 | sherbrooke
# Processing Record 17 of Set 8 | lazdijai
# Processing Record 18 of Set 8 | tigzirt
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | danane
# Processing Record 21 of Set 8 | kozhva
# Processing Record 22 of Set 8 | jimma
# Processing Record 23 of Set 8 | nantucket
# Processing Record 24 of Set 8 | korla
# Processing Record 25 of Set 8 | vostok
# Processing Record 26 of Set 8 | shingu
# Processing Record 27 of Set 8 | barcelos
# Processing Record 28 of Set 8 | lamu
# Processing Record 29 of Set 8 | bahia blanca
# Processing Record 30 of Set 8 | puri
# Processing Record 31 of Set 8 | boa vista
# Processing Record 32 of Set 8 | biltine
# Processing Record 33 of Set 8 | lanzhou
# Processing Record 34 of Set 8 | khairagarh
# Processing Record 35 of Set 8 | axim
# Processing Record 36 of Set 8 | banda aceh
# Processing Record 37 of Set 8 | alamosa
# Processing Record 38 of Set 8 | norman wells
# Processing Record 39 of Set 8 | lodja
# Processing Record 40 of Set 8 | pandanon
# City not found. Skipping...
# Processing Record 41 of Set 8 | hai duong
# Processing Record 42 of Set 8 | khandagayty
# Processing Record 43 of Set 8 | sturgeon bay
# Processing Record 44 of Set 8 | seoul
# Processing Record 45 of Set 8 | gigmoto
# Processing Record 46 of Set 8 | huarmey
# Processing Record 47 of Set 8 | scarborough
# Processing Record 48 of Set 8 | oak ridge
# Processing Record 49 of Set 8 | zabol
# Processing Record 50 of Set 8 | ginir
# Processing Record 1 of Set 9 | okhotsk
# Processing Record 2 of Set 9 | la asuncion
# Processing Record 3 of Set 9 | yomou
# Processing Record 4 of Set 9 | lakatoro
# Processing Record 5 of Set 9 | lang suan
# Processing Record 6 of Set 9 | makakilo city
# Processing Record 7 of Set 9 | yaqui
# Processing Record 8 of Set 9 | college
# Processing Record 9 of Set 9 | praia da vitoria
# Processing Record 10 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 9 | ende
# Processing Record 12 of Set 9 | kyra
# Processing Record 13 of Set 9 | cubuk
# Processing Record 14 of Set 9 | portland
# Processing Record 15 of Set 9 | hammonton
# Processing Record 16 of Set 9 | brigantine
# Processing Record 17 of Set 9 | donskoye
# Processing Record 18 of Set 9 | bolonchen
# City not found. Skipping...
# Processing Record 19 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 20 of Set 9 | sisimiut
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | owerri
# Processing Record 23 of Set 9 | aswan
# Processing Record 24 of Set 9 | akola
# Processing Record 25 of Set 9 | dasoguz
# Processing Record 26 of Set 9 | beira
# Processing Record 27 of Set 9 | saint pete beach
# Processing Record 28 of Set 9 | qianan
# Processing Record 29 of Set 9 | sao miguel do araguaia
# Processing Record 30 of Set 9 | emiliano zapata
# Processing Record 31 of Set 9 | lamar
# Processing Record 32 of Set 9 | klyuchi
# Processing Record 33 of Set 9 | ankazobe
# Processing Record 34 of Set 9 | krupina
# Processing Record 35 of Set 9 | blue springs
# Processing Record 36 of Set 9 | sundsvall
# Processing Record 37 of Set 9 | moose factory
# Processing Record 38 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 9 | sibolga
# Processing Record 40 of Set 9 | kuching
# Processing Record 41 of Set 9 | kahului
# Processing Record 42 of Set 9 | lavrentiya
# Processing Record 43 of Set 9 | hanna
# Processing Record 44 of Set 9 | fort nelson
# Processing Record 45 of Set 9 | funtua
# Processing Record 46 of Set 9 | kisangani
# Processing Record 47 of Set 9 | campos belos
# Processing Record 48 of Set 9 | itarare
# Processing Record 49 of Set 9 | tiznit
# Processing Record 50 of Set 9 | lemon tree passage
# Processing Record 1 of Set 10 | talaya
# Processing Record 2 of Set 10 | ikalamavony
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | dalaba
# Processing Record 5 of Set 10 | san rafael
# Processing Record 6 of Set 10 | abashiri
# Processing Record 7 of Set 10 | grand-santi
# Processing Record 8 of Set 10 | mindyak
# Processing Record 9 of Set 10 | picayune
# Processing Record 10 of Set 10 | opoczno
# Processing Record 11 of Set 10 | praia
# Processing Record 12 of Set 10 | puerto carreno
# Processing Record 13 of Set 10 | tagusao
# Processing Record 14 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 10 | mtama
# Processing Record 16 of Set 10 | broome
# Processing Record 17 of Set 10 | hamilton
# Processing Record 18 of Set 10 | kamaishi
# Processing Record 19 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 10 | maicao
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 23 of Set 10 | athens
# Processing Record 24 of Set 10 | chimore
# Processing Record 25 of Set 10 | berga
# Processing Record 26 of Set 10 | adet
# Processing Record 27 of Set 10 | haverfordwest
# Processing Record 28 of Set 10 | shellbrook
# Processing Record 29 of Set 10 | kalanguy
# Processing Record 30 of Set 10 | dano
# Processing Record 31 of Set 10 | general teran
# Processing Record 32 of Set 10 | el ocotito
# Processing Record 33 of Set 10 | kaitangata
# Processing Record 34 of Set 10 | lasa
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | villaviciosa
# Processing Record 37 of Set 10 | le port
# Processing Record 38 of Set 10 | qiongshan
# Processing Record 39 of Set 10 | ngunguru
# Processing Record 40 of Set 10 | bhawanipatna
# Processing Record 41 of Set 10 | sampit
# Processing Record 42 of Set 10 | namibe
# Processing Record 43 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 44 of Set 10 | kysyl-syr
# Processing Record 45 of Set 10 | maltahohe
# Processing Record 46 of Set 10 | bratsk
# Processing Record 47 of Set 10 | road town
# Processing Record 48 of Set 10 | afua
# Processing Record 49 of Set 10 | richards bay
# Processing Record 50 of Set 10 | kavaratti
# Processing Record 1 of Set 11 | jumla
# Processing Record 2 of Set 11 | sisophon
# Processing Record 3 of Set 11 | auki
# Processing Record 4 of Set 11 | mahibadhoo
# Processing Record 5 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 6 of Set 11 | mandurah
# Processing Record 7 of Set 11 | tres coracoes
# Processing Record 8 of Set 11 | berlevag
# Processing Record 9 of Set 11 | dingle
# Processing Record 10 of Set 11 | meulaboh
# Processing Record 11 of Set 11 | goundam
# Processing Record 12 of Set 11 | nador
# Processing Record 13 of Set 11 | olafsvik
# Processing Record 14 of Set 11 | miri
# Processing Record 15 of Set 11 | kununurra
# Processing Record 16 of Set 11 | high level
# Processing Record 17 of Set 11 | lengshuitan
# Processing Record 18 of Set 11 | alice springs
# Processing Record 19 of Set 11 | muisne
# Processing Record 20 of Set 11 | beidao
# Processing Record 21 of Set 11 | nivala
# Processing Record 22 of Set 11 | wajima
# Processing Record 23 of Set 11 | copiapo
# Processing Record 24 of Set 11 | sorong
# Processing Record 25 of Set 11 | verkhnetulomskiy
# Processing Record 26 of Set 11 | sale
# Processing Record 27 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 28 of Set 11 | shirvan
# Processing Record 29 of Set 11 | vuktyl
# Processing Record 30 of Set 11 | great yarmouth
# Processing Record 31 of Set 11 | teluknaga
# Processing Record 32 of Set 11 | makhachkala
# Processing Record 33 of Set 11 | port lincoln
# Processing Record 34 of Set 11 | tattayyangarpettai
# Processing Record 35 of Set 11 | saint-pierre
# Processing Record 36 of Set 11 | pasighat
# Processing Record 37 of Set 11 | awjilah
# Processing Record 38 of Set 11 | dustlik
# Processing Record 39 of Set 11 | sivas
# Processing Record 40 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 11 | rojhan
# Processing Record 42 of Set 11 | lukovetskiy
# Processing Record 43 of Set 11 | turayf
# Processing Record 44 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 11 | arrifes
# Processing Record 46 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 47 of Set 11 | neyshabur
# Processing Record 48 of Set 11 | san carlos de bariloche
# Processing Record 49 of Set 11 | methoni
# Processing Record 50 of Set 11 | cabinda
# Processing Record 1 of Set 12 | hovd
# Processing Record 2 of Set 12 | dibulla
# Processing Record 3 of Set 12 | mulege
# Processing Record 4 of Set 12 | inuvik
# Processing Record 5 of Set 12 | tromso
# Processing Record 6 of Set 12 | cururupu
# Processing Record 7 of Set 12 | west des moines
# Processing Record 8 of Set 12 | edd
# Processing Record 9 of Set 12 | surgut
# Processing Record 10 of Set 12 | galesong
# Processing Record 11 of Set 12 | nemuro
# Processing Record 12 of Set 12 | lalmohan
# Processing Record 13 of Set 12 | camana
# Processing Record 14 of Set 12 | san lazaro
# Processing Record 15 of Set 12 | lucapa
# Processing Record 16 of Set 12 | sobolevo
# Processing Record 17 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 12 | havelock
# Processing Record 19 of Set 12 | poso
# Processing Record 20 of Set 12 | kamthi
# Processing Record 21 of Set 12 | nipawin
# Processing Record 22 of Set 12 | vardo
# Processing Record 23 of Set 12 | aktash
# Processing Record 24 of Set 12 | havre-saint-pierre
# Processing Record 25 of Set 12 | la tuque
# Processing Record 26 of Set 12 | solwezi
# Processing Record 27 of Set 12 | rocha
# Processing Record 28 of Set 12 | mugur-aksy
# Processing Record 29 of Set 12 | zheleznodorozhnyy
# Processing Record 30 of Set 12 | kulhudhuffushi
# Processing Record 31 of Set 12 | rabo de peixe
# Processing Record 32 of Set 12 | post falls
# Processing Record 33 of Set 12 | sayat
# Processing Record 34 of Set 12 | russko-vysotskoye
# Processing Record 35 of Set 12 | say
# Processing Record 36 of Set 12 | fukue
# Processing Record 37 of Set 12 | weihai
# Processing Record 38 of Set 12 | ponta delgada
# Processing Record 39 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 12 | saldanha
# Processing Record 41 of Set 12 | dakar
# Processing Record 42 of Set 12 | bonavista
# Processing Record 43 of Set 12 | solnechnyy
# Processing Record 44 of Set 12 | guiyang
# Processing Record 45 of Set 12 | bafata
# Processing Record 46 of Set 12 | leh
# Processing Record 47 of Set 12 | imbituba
# Processing Record 48 of Set 12 | morro bay
# Processing Record 49 of Set 12 | najran
# Processing Record 50 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 1 of Set 13 | pringsewu
# Processing Record 2 of Set 13 | nelson bay
# Processing Record 3 of Set 13 | shitanjing
# Processing Record 4 of Set 13 | los llanos de aridane
# Processing Record 5 of Set 13 | alice town
# Processing Record 6 of Set 13 | matay
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | sembe
# Processing Record 9 of Set 13 | walvis bay
# Processing Record 10 of Set 13 | bitlis
# Processing Record 11 of Set 13 | mangrol
# Processing Record 12 of Set 13 | cockburn town
# Processing Record 13 of Set 13 | mehamn
# Processing Record 14 of Set 13 | nadym
# Processing Record 15 of Set 13 | bentiu
# Processing Record 16 of Set 13 | aksha
# Processing Record 17 of Set 13 | alugan
# Processing Record 18 of Set 13 | cotonou
# Processing Record 19 of Set 13 | linxi
# Processing Record 20 of Set 13 | tete
# Processing Record 21 of Set 13 | puerto suarez
# Processing Record 22 of Set 13 | nuevitas
# Processing Record 23 of Set 13 | kiunga
# Processing Record 24 of Set 13 | hastings
# Processing Record 25 of Set 13 | svetlaya
# Processing Record 26 of Set 13 | padang
# Processing Record 27 of Set 13 | buchanan
# Processing Record 28 of Set 13 | deep river
# Processing Record 29 of Set 13 | amga
# Processing Record 30 of Set 13 | nuuk
# Processing Record 31 of Set 13 | kongolo
# Processing Record 32 of Set 13 | colares
# Processing Record 33 of Set 13 | chapais
# Processing Record 34 of Set 13 | fort wellington
# Processing Record 35 of Set 13 | coquimbo
# Processing Record 36 of Set 13 | mulchen
# Processing Record 37 of Set 13 | marienburg
# Processing Record 38 of Set 13 | panama city
# Processing Record 39 of Set 13 | gizo
# Processing Record 40 of Set 13 | bilma
# Processing Record 41 of Set 13 | ouahigouya
# Processing Record 42 of Set 13 | durazno
# Processing Record 43 of Set 13 | trelew
# Processing Record 44 of Set 13 | garachine
# Processing Record 45 of Set 13 | bac lieu
# Processing Record 46 of Set 13 | songjianghe
# Processing Record 47 of Set 13 | cozumel
# Processing Record 48 of Set 13 | gunjur
# Processing Record 49 of Set 13 | takoradi
# Processing Record 50 of Set 13 | kayasula
# Processing Record 1 of Set 14 | borogontsy
# Processing Record 2 of Set 14 | mirnyy
# Processing Record 3 of Set 14 | kuminskiy
# Processing Record 4 of Set 14 | platteville
# Processing Record 5 of Set 14 | suntar
# Processing Record 6 of Set 14 | shanghai
# Processing Record 7 of Set 14 | chapada dos guimaraes
# Processing Record 8 of Set 14 | mount gambier
# Processing Record 9 of Set 14 | port moresby
# Processing Record 10 of Set 14 | diamantino
# Processing Record 11 of Set 14 | eufaula
# Processing Record 12 of Set 14 | rio gallegos
# Processing Record 13 of Set 14 | araguatins
# City not found. Skipping...
# Processing Record 14 of Set 14 | sheridan
# Processing Record 15 of Set 14 | keetmanshoop
# Processing Record 16 of Set 14 | serebryansk
# Processing Record 17 of Set 14 | santa luzia
# Processing Record 18 of Set 14 | puerto escondido
# Processing Record 19 of Set 14 | kieta
# Processing Record 20 of Set 14 | marawi
# Processing Record 21 of Set 14 | maarianhamina
# Processing Record 22 of Set 14 | north bend
# Processing Record 23 of Set 14 | vallenar
# Processing Record 24 of Set 14 | berdyuzhye
# City not found. Skipping...
# Processing Record 25 of Set 14 | heide
# Processing Record 26 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 14 | yatou
# Processing Record 28 of Set 14 | piacabucu
# Processing Record 29 of Set 14 | bhubaneswar
# Processing Record 30 of Set 14 | acquaviva delle fonti
# Processing Record 31 of Set 14 | kokopo
# Processing Record 32 of Set 14 | komsomolskiy
# Processing Record 33 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 34 of Set 14 | karasjok
# Processing Record 35 of Set 14 | ciudad guayana
# Processing Record 36 of Set 14 | omboue
# Processing Record 37 of Set 14 | toul
# Processing Record 38 of Set 14 | filadelfia
# Processing Record 39 of Set 14 | taltal
# Processing Record 40 of Set 14 | tabuk
# Processing Record 41 of Set 14 | rozkishne
# Processing Record 42 of Set 14 | boden
# Processing Record 43 of Set 14 | sabha
# Processing Record 44 of Set 14 | saint-joseph
# Processing Record 45 of Set 14 | pando
# Processing Record 46 of Set 14 | san rafael del sur
# Processing Record 47 of Set 14 | morgan city
# Processing Record 48 of Set 14 | metehara
# City not found. Skipping...
# Processing Record 49 of Set 14 | havre
# Processing Record 50 of Set 14 | biak
# Processing Record 1 of Set 15 | mercedes
# Processing Record 2 of Set 15 | arman
# Processing Record 3 of Set 15 | san luis
# Processing Record 4 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 15 | khandyga
# Processing Record 6 of Set 15 | mastic beach
# Processing Record 7 of Set 15 | fonte boa
# Processing Record 8 of Set 15 | dvinskoy
# Processing Record 9 of Set 15 | alofi
# Processing Record 10 of Set 15 | teknaf
# Processing Record 11 of Set 15 | avera
# Processing Record 12 of Set 15 | belaya gora
# Processing Record 13 of Set 15 | calabozo
# Processing Record 14 of Set 15 | zhangjiakou
# Processing Record 15 of Set 15 | skjervoy
# Processing Record 16 of Set 15 | naze
# Processing Record 17 of Set 15 | aykhal
# Processing Record 18 of Set 15 | kuloy
# Processing Record 19 of Set 15 | inhambane
# Processing Record 20 of Set 15 | manacapuru
# Processing Record 21 of Set 15 | onega
# Processing Record 22 of Set 15 | tazovskiy
# Processing Record 23 of Set 15 | cayenne
# Processing Record 24 of Set 15 | mudon
# Processing Record 25 of Set 15 | republic
# Processing Record 26 of Set 15 | kaseda
# Processing Record 27 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 15 | bereda
# Processing Record 29 of Set 15 | goderich
# Processing Record 30 of Set 15 | reitz
# Processing Record 31 of Set 15 | icod de los vinos
# Processing Record 32 of Set 15 | ulze
# City not found. Skipping...
# Processing Record 33 of Set 15 | jiwani
# Processing Record 34 of Set 15 | polovinnoye
# Processing Record 35 of Set 15 | ritchie
# Processing Record 36 of Set 15 | westport
# Processing Record 37 of Set 15 | suicheng
# Processing Record 38 of Set 15 | mayo
# Processing Record 39 of Set 15 | la ronge
# Processing Record 40 of Set 15 | kuusamo
# Processing Record 41 of Set 15 | alexandria
# Processing Record 42 of Set 15 | puerto del rosario
# Processing Record 43 of Set 15 | vaitape
# Processing Record 44 of Set 15 | labytnangi
# Processing Record 45 of Set 15 | saint-leu
# Processing Record 46 of Set 15 | lastoursville
# Processing Record 47 of Set 15 | moerai
# Processing Record 48 of Set 15 | bilibino
# Processing Record 49 of Set 15 | vanavara
# Processing Record 50 of Set 15 | bonthe
# Processing Record 1 of Set 16 | ordzhonikidze
# Processing Record 2 of Set 16 | pierre
# Processing Record 3 of Set 16 | carlsbad
# Processing Record 4 of Set 16 | bar harbor
# Processing Record 5 of Set 16 | itarema
# Processing Record 6 of Set 16 | matagami
# Processing Record 7 of Set 16 | colimes
# Processing Record 8 of Set 16 | mount isa
# Processing Record 9 of Set 16 | karratha
# Processing Record 10 of Set 16 | sopelana
# Processing Record 11 of Set 16 | ulaanbaatar
# Processing Record 12 of Set 16 | kumluca
# Processing Record 13 of Set 16 | kendari
# Processing Record 14 of Set 16 | stamsund
# City not found. Skipping...
# Processing Record 15 of Set 16 | juneau
# Processing Record 16 of Set 16 | roquetas de mar
# Processing Record 17 of Set 16 | crateus
# Processing Record 18 of Set 16 | dali
# Processing Record 19 of Set 16 | santa cruz
# Processing Record 20 of Set 16 | deputatskiy
# Processing Record 21 of Set 16 | antofagasta
# Processing Record 22 of Set 16 | cidreira
# Processing Record 23 of Set 16 | kasongo
# Processing Record 24 of Set 16 | mosquera
# Processing Record 25 of Set 16 | giaginskaya
# Processing Record 26 of Set 16 | balabac
# Processing Record 27 of Set 16 | bowen
# Processing Record 28 of Set 16 | ust-barguzin
# Processing Record 29 of Set 16 | chaman
# Processing Record 30 of Set 16 | port augusta
# Processing Record 31 of Set 16 | pirsagi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Mataura -46.19  168.86     46.00        97          96        1.99
# 1     Salinopolis  -0.61  -47.36     85.03        67          43       11.21
# 2           Pevek  69.70  170.31     38.48        88         100        3.47
# 3          Luanda  -8.84   13.23     75.20        83          20        9.17
# 4           Ancud -41.87  -73.82     48.00       100          90        3.36
# 5  Port Elizabeth -33.92   25.57     60.80        77           0        3.36
# 6          Barrow  71.29 -156.79     44.60        93          90        9.17
# 7     East London -33.02   27.91     62.31        60           0        5.86
# 8      Codrington -38.27  141.97     46.60        81          84       21.99
# 9  Vestmannaeyjar  63.44  -20.27     53.60        76          38       17.22
#
#         Description Country
# 0        light rain      NZ
# 1  scattered clouds      BR
# 2   overcast clouds      RU
# 3        few clouds      AO
# 4   overcast clouds      CL
# 5         clear sky      ZA
# 6               fog      US
# 7         clear sky      ZA
# 8     moderate rain      AU
# 9  scattered clouds      IS

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
